# %%
import json
import matplotlib.pyplot as plt

# %%
with open('convergence.json') as f:
    res = json.load(f)

# %%
plt.loglog(res['grids'], res['errors'], 'o-')
plt.xticks(ticks=res['grids'], labels=res['grids'])
plt.yticks(ticks=res['errors'], labels=res['errors']);
